# %% [markdown]
# # 第四次作业及一些相关的知识
#
# ## numpy的一些矩阵操作
#
# 可以参考：https://docs.scipy.org/doc/numpy/reference/routines.linalg.html

# %%
import numpy as np

# 生成 1 到 -1 之间的一个均匀分布
a = 2*np.random.random(size=12).reshape((2,3,2)) - 1  # 注意减一操作是广播到所有元素

# 生成 均值0 方差0.2 的一个正太分布
b = np.random.normal(0,0.2,12)  

print('a = ', a)
print('b = ', b)
# Out:
# a =  [[[-0.85626666  0.83253307]
#   [-0.98571982 -0.26904625]
#   [ 0.09716794 -0.33110291]]
#
#  [[-0.14789347  0.08276307]
#   [-0.81146461  0.71757283]
#   [ 0.50922196 -0.97795837]]]
# b =  [ 0.07827382  0.19977414  0.08452066 -0.04416182 -0.15103201  0.11445352
#   0.11351084  0.09403271  0.04909157 -0.17649568 -0.60519009  0.29211669]

# %% [markdown]
# 请你创建三个矩阵$A, B, C$，它们都是服从标准正太分布的矩阵，其中$A$的大小为$200\times 400$，$B$的大小为$400\times 400$，$C$的大小为$400\times 1$.

# %%
import numpy as np
np.random.seed(1)

'''
添加你的代码
'''
A = np.random.uniform(size=80000).reshape(200,400)
B = np.random.uniform(size=160000).reshape(400,400)
C = np.random.uniform(size=400).reshape(400,1)
print(A)
print(B)
print(C)
# Out:
# [[4.17022005e-01 7.20324493e-01 1.14374817e-04 ... 7.49858311e-01
#   5.11141478e-01 5.40951805e-01]
#  [9.59434321e-01 8.03960891e-01 3.23230666e-02 ... 5.44121384e-01
#   4.87921492e-01 8.55356413e-01]
#  [8.88386434e-01 1.84384442e-01 5.85348459e-01 ... 1.51375570e-01
#   6.35370961e-01 8.47788044e-01]
#  ...
#  [5.57400654e-02 6.94224620e-01 5.21778734e-02 ... 4.35078362e-02
#   2.69507229e-02 9.28292763e-02]
#  [6.22422871e-01 4.47538135e-01 7.72233027e-01 ... 6.84000483e-01
#   2.34395759e-01 8.59277158e-03]
#  [4.40050533e-01 6.03226178e-01 9.17375990e-01 ... 9.03794141e-01
#   9.10375201e-01 6.70335111e-01]]
# [[0.18858853 0.72031626 0.92507572 ... 0.78693302 0.2622553  0.72137144]
#  [0.97596241 0.16140768 0.38648831 ... 0.95918704 0.49160396 0.02518502]
#  [0.50240079 0.21560115 0.76526318 ... 0.52618375 0.5383103  0.80405855]
#  ...
#  [0.19287088 0.95446628 0.56260513 ... 0.28257396 0.61188256 0.22116045]
#  [0.75141174 0.67482016 0.45769516 ... 0.27802288 0.53791449 0.18314713]
#  [0.97702835 0.77128685 0.33273972 ... 0.63351547 0.52296202 0.90151801]]
# [[0.67935036]
#  [0.53606537]
#  [0.6400028 ]
#  [0.17792295]
#  [0.91938008]
#  [0.06383202]
#  [0.69042494]
#  [0.92804896]
#  [0.68827586]
#  [0.13496278]
#  [0.96153768]
#  [0.48313078]
#  [0.99638171]
#  [0.88239107]
#  [0.23407329]
#  [0.83636566]
#  [0.10213861]
#  [0.0248805 ]
#  [0.90861584]
#  [0.06001786]
#  [0.07645444]
#  [0.24250126]
#  [0.36812736]
#  [0.90296789]
#  [0.50650374]
#  [0.03983422]
#  [0.92522868]
#  [0.72757932]
#  [0.20782139]
#  [0.91425133]
#  [0.19693981]
#  [0.62871099]
#  [0.07415653]
#  [0.15700436]
#  [0.00714858]
#  [0.59162419]
#  [0.63260782]
#  [0.09257984]
#  [0.35101345]
#  [0.77559001]
#  [0.71829544]
#  [0.15315061]
#  [0.12021152]
#  [0.92484208]
#  [0.26617181]
#  [0.04231529]
#  [0.06944595]
#  [0.82223021]
#  [0.72906084]
#  [0.79569891]
#  [0.62332295]
#  [0.16060819]
#  [0.90779243]
#  [0.16322586]
#  [0.85030883]
#  [0.09109007]
#  [0.49143012]
#  [0.73635442]
#  [0.50241119]
#  [0.50478582]
#  [0.38992655]
#  [0.31998468]
#  [0.62836478]
#  [0.17398463]
#  [0.73461982]
#  [0.43913388]
#  [0.52782507]
#  [0.62417032]
#  [0.37813166]
#  [0.93740525]
#  [0.9146377 ]
#  [0.07100643]
#  [0.21865287]
#  [0.78481947]
#  [0.39444361]
#  [0.61957583]
#  [0.46457695]
#  [0.51490088]
#  [0.59938303]
#  [0.94431553]
#  [0.63343682]
#  [0.48835619]
#  [0.7876663 ]
#  [0.68291487]
#  [0.01435732]
#  [0.38469262]
#  [0.75371097]
#  [0.82506075]
#  [0.79022407]
#  [0.16533702]
#  [0.50392701]
#  [0.12782222]
#  [0.62705605]
#  [0.13202642]
#  [0.97926936]
#  [0.49523584]
#  [0.57949963]
#  [0.12865342]
#  [0.08012609]
#  [0.64798095]
#  [0.34203088]
#  [0.19858997]
#  [0.47372621]
#  [0.34600971]
#  [0.34716576]
#  [0.20624794]
#  [0.45096712]
#  [0.27374321]
#  [0.10622262]
#  [0.71120257]
#  [0.41028283]
#  [0.31041031]
#  [0.98635008]
#  [0.93635008]
#  [0.12675841]
#  [0.20485829]
#  [0.96748295]
#  [0.98035368]
#  [0.81590243]
#  [0.4250032 ]
#  [0.80599502]
#  [0.93081837]
#  [0.27529325]
#  [0.80947397]
#  [0.25113659]
#  [0.61889718]
#  [0.29866229]
#  [0.24642743]
#  [0.57086584]
#  [0.57537931]
#  [0.92899694]
#  [0.80279985]
#  [0.19920131]
#  [0.39147958]
#  [0.63411008]
#  [0.79817119]
#  [0.40982515]
#  [0.12885788]
#  [0.53500684]
#  [0.82338035]
#  [0.3083404 ]
#  [0.22198912]
#  [0.60933132]
#  [0.37768338]
#  [0.31805979]
#  [0.63366671]
#  [0.96528926]
#  [0.42574332]
#  [0.28187328]
#  [0.89534035]
#  [0.59279273]
#  [0.00679643]
#  [0.62198431]
#  [0.40342258]
#  [0.87263839]
#  [0.09435233]
#  [0.53368866]
#  [0.81500537]
#  [0.32384992]
#  [0.24551673]
#  [0.11086872]
#  [0.51150037]
#  [0.91852168]
#  [0.8489573 ]
#  [0.32118877]
#  [0.56313321]
#  [0.62942003]
#  [0.51610436]
#  [0.639541  ]
#  [0.55755582]
#  [0.84133906]
#  [0.45070043]
#  [0.2689233 ]
#  [0.41449994]
#  [0.21896087]
#  [0.9736345 ]
#  [0.42216944]
#  [0.66075406]
#  [0.31249077]
#  [0.41164591]
#  [0.79172167]
#  [0.72411089]
#  [0.98855369]
#  [0.90528188]
#  [0.73162482]
#  [0.55055532]
#  [0.4237544 ]
#  [0.22438232]
#  [0.46957055]
#  [0.53759246]
#  [0.16639954]
#  [0.64355706]
#  [0.14521579]
#  [0.99688412]
#  [0.39650566]
#  [0.02149501]
#  [0.76570431]
#  [0.70315082]
#  [0.44108326]
#  [0.23740443]
#  [0.1132556 ]
#  [0.57448013]
#  [0.53366311]
#  [0.70218085]
#  [0.80799712]
#  [0.25560166]
#  [0.10397054]
#  [0.34886322]
#  [0.82955016]
#  [0.0209325 ]
#  [0.11392531]
#  [0.05713001]
#  [0.43777068]
#  [0.58410881]
#  [0.58007699]
#  [0.6553178 ]
#  [0.72023184]
#  [0.80191799]
#  [0.43015906]
#  [0.72739316]
#  [0.15476035]
#  [0.36756205]
#  [0.68895403]
#  [0.22211629]
#  [0.53609591]
#  [0.00683852]
#  [0.15131825]
#  [0.78446766]
#  [0.61313872]
#  [0.8582447 ]
#  [0.14794054]
#  [0.81358148]
#  [0.75239562]
#  [0.3660877 ]
#  [0.97101938]
#  [0.46968568]
#  [0.59020218]
#  [0.25359681]
#  [0.2840679 ]
#  [0.98730278]
#  [0.98957467]
#  [0.27018088]
#  [0.90502471]
#  [0.45992089]
#  [0.98926319]
#  [0.71632427]
#  [0.39145513]
#  [0.28286843]
#  [0.83676994]
#  [0.01908515]
#  [0.20063797]
#  [0.34702318]
#  [0.05477432]
#  [0.53069127]
#  [0.40951848]
#  [0.12229722]
#  [0.72998161]
#  [0.868086  ]
#  [0.66288817]
#  [0.39499536]
#  [0.56652132]
#  [0.82081573]
#  [0.06276425]
#  [0.4141578 ]
#  [0.95391774]
#  [0.86672632]
#  [0.99530021]
#  [0.32517251]
#  [0.81686598]
#  [0.04463396]
#  [0.92617644]
#  [0.27078576]
#  [0.71269017]
#  [0.47385309]
#  [0.38658621]
#  [0.76189685]
#  [0.13899615]
#  [0.48873272]
#  [0.84117867]
#  [0.97906844]
#  [0.07394212]
#  [0.9920008 ]
#  [0.95432797]
#  [0.00806972]
#  [0.41904807]
#  [0.80730678]
#  [0.25006539]
#  [0.44627446]
#  [0.08626955]
#  [0.78439126]
#  [0.14000485]
#  [0.17648371]
#  [0.3006081 ]
#  [0.31273344]
#  [0.96151459]
#  [0.79649985]
#  [0.41952697]
#  [0.58828891]
#  [0.33919889]
#  [0.27489394]
#  [0.31067794]
#  [0.00911457]
#  [0.18555224]
#  [0.60866472]
#  [0.51502503]
#  [0.28244561]
#  [0.0649787 ]
#  [0.07385166]
#  [0.42624593]
#  [0.59732573]
#  [0.34959795]
#  [0.89707789]
#  [0.97043632]
#  [0.78769659]
#  [0.44914634]
#  [0.78190511]
#  [0.7036604 ]
#  [0.30120895]
#  [0.96886458]
#  [0.92316308]
#  [0.91499871]
#  [0.32143124]
#  [0.83336909]
#  [0.37256881]
#  [0.18724674]
#  [0.48855083]
#  [0.35171586]
#  [0.48209407]
#  [0.01107219]
#  [0.26661876]
#  [0.66178804]
#  [0.92327142]
#  [0.5063504 ]
#  [0.09730419]
#  [0.10046131]
#  [0.22166731]
#  [0.87581986]
#  [0.5708258 ]
#  [0.11086469]
#  [0.15583349]
#  [0.1999067 ]
#  [0.08778882]
#  [0.06070477]
#  [0.91063043]
#  [0.25170034]
#  [0.62070979]
#  [0.3415796 ]
#  [0.275262  ]
#  [0.641122  ]
#  [0.9762234 ]
#  [0.49234092]
#  [0.54645342]
#  [0.31365972]
#  [0.88264068]
#  [0.4323064 ]
#  [0.4267085 ]
#  [0.22773054]
#  [0.14760388]
#  [0.84281717]
#  [0.04872133]
#  [0.62168687]
#  [0.66123727]
#  [0.57250262]
#  [0.65221674]
#  [0.69975507]
#  [0.03016386]
#  [0.93338156]
#  [0.6431079 ]
#  [0.96267516]
#  [0.18896589]
#  [0.78174837]
#  [0.57460795]
#  [0.43570892]
#  [0.42854925]
#  [0.92863793]
#  [0.28278379]
#  [0.20127778]
#  [0.69256254]
#  [0.39353993]
#  [0.55838756]
#  [0.16160002]
#  [0.25068433]
#  [0.93720183]
#  [0.12161656]
#  [0.19933938]
#  [0.85330631]
#  [0.75117274]
#  [0.26357126]
#  [0.75870185]
#  [0.10724872]
#  [0.81318149]
#  [0.18744753]
#  [0.24142805]
#  [0.15414105]
#  [0.06343066]
#  [0.06883124]
#  [0.48170176]
#  [0.93783122]
#  [0.08217927]
#  [0.26123671]]

# %% [markdown]
# ### 1.计算$A+A$,$AA^T$,$A^TA$,$AB$. 然后写一个函数对于参数$\lambda$，计算$A(B-\lambda I)$.

# %%
# 作业：添加你的代码

# %% [markdown]
# ### 2.计算$Bx=C$的解。

# %%
# 作业：添加你的代码

# %% [markdown]
# ## 向量范数
#
#     1-范数： ，即向量元素绝对值之和，matlab调用函数norm(x, 1) 。
#     2-范数：，Euclid范数（欧几里得范数，常用计算向量长度），即向量元素绝对值的平方和再开方，matlab调用函数norm(x, 2)。
#      ∞-范数：，即所有向量元素绝对值中的最大值，matlab调用函数norm(x, inf)。
#      −∞-范数：，即所有向量元素绝对值中的最小值，matlab调用函数norm(x, -inf)。
#     p-范数：，即向量元素绝对值的p次方和的1/p次幂，matlab调用函数norm(x, p)。
#
# ## 矩阵范数
#
#     1-范数：， 列和范数，即所有矩阵列向量绝对值之和的最大值，matlab调用函数norm(A, 1)。
#     2-范数：，为的最大特征值。，谱范数，即A'A矩阵的最大特征值的开平方。matlab调用函数norm(x, 2)。-范数：，行和范数，即所有矩阵行向量绝对值之和的最大值，matlab调用函数norm(A, inf)。
#     F-范数：，Frobenius范数，即矩阵元素绝对值的平方和再开平方，matlab调用函数norm(A, ’fro‘)。
#     核范数：是A的奇异值。
#
# 矩阵范数：矩阵A的2范数就是 A的转置乘以A矩阵特征根 最大值的开根号； 向量范数：向量x的2范数是x中各个元素平方之和再开根号； 函数范数：函数f(x)的2范数是x在区间（a,b）上f(x)的平方的积分再开根号。
#
# 2-范数：║A║2 = A的最大奇异值 = ( max{ λi(A*A^H) } ) ^{1/2} (欧几里德范数,谱范数,即AA'特征值λi中最大者λ1的平方根，其中A^H为A的转置共轭矩阵)。
#
# 引自： https://cloud.tencent.com/developer/article/1101927
#
# ### 3.计算$A$的Frobenius范数$||A||_F$、$B$的无穷范数$||B||_\infty$。

# %%
# 作业：添加你的代码

# %% [markdown]
# ### 矩阵特征值
#
# numpy的矩阵特征值计算提供了两组函数，一组用于通用的矩阵，一组用于赫米特矩阵。另外，每组中又包含两个函数，分别用于只计算特征值，以及特征向量。
#
# 1. `w, v = np.linalg.eig(a)`，计算一个方阵的特征值和特征向量，其中特征向量v是归一化后的向量。
# 2. `w, v = np.linalg.eigh(a, UPLO='L')`，用于赫米特矩阵的特征值计算。其中`UPLO`的取值`L`与`U`分别表示计算时采用`a`的下三角还是上三角矩阵。
# 3. `w = np.linalg.eigvals(a)`，与1.的最大差别就是没有计算特征向量。
# 4. `w = np.linalg.eigvalsh(a)`，与2.的最大差别就是没有计算特征向量。
#
# ### 4.求解 $A$的特征值的最大和最小值以及对应的特征向量。

# %%
# 作业：添加你的代码

# %% [markdown]
# # 奇异值分解（SVD）

# %% [markdown]
# SVD将原始的矩阵$Data$分解成三个矩阵$U$,$\Sigma$,和$V^T$，如果原始矩阵$Data$是$m$行$n$列，那么$U$,$\Sigma$,和$V^T$就分别是$m$行$m$列、$m$行$n$列和$n$行$n$列。
#
# 为了清晰起见，上述过程可以写成如下一行：$$Data_{m\times n}=U_{m\times m}\Sigma_{m \times n}V^T_{n\times n}$$
#
# 上述分解中会构建出一个矩阵$\Sigma$，该矩阵只有对角元素，其他元素均为0. 另一个惯例就是，$\Sigma$的对角元素是从大到小排列的。这些对角元素称为奇异值（Singular Value），它们就是矩阵$Data Data^{T}$特征值的平方根。
#
# 在科学工程中，一直存在这样一个普遍事实：在某个奇异值的数目（$r$个）之后，其他的奇异值都置为0.这就意味着数据集中仅有$r$个重要特征，而其余特征则都是噪声或冗余特征。

# %%
import numpy as np
U, Sigma, VT = np.linalg.svd([[1, 1], [7, 7]])
print('U = ', U)
print('Sigma = ', Sigma)
print('VT = ', VT)

# %% [markdown]
# 可以看到矩阵$\Sigma$是以对角线元素组成的行向量返回。
#
# 接下来我们再来看一个更大的例子。

# %%
data = [[1, 1, 1, 0, 0],
        [2, 2, 2, 0, 0],
        [1, 1, 1, 0, 0],
        [5, 5, 5, 0, 0],
        [1, 1, 0, 2, 2],
        [0, 0, 0, 3, 3],
        [0, 0, 0, 1, 1]]

U, Sigma, VT = np.linalg.svd(data)
print(Sigma)

# %% [markdown]
# 可以看到$\Sigma$中前3个数值比其他的值大了很多，说明前3个奇异值蕴含了矩阵中大量的特征信息，所以我们就可以用如下结果来近似原矩阵
# $$Data_{m\times n}\approx U_{m\times 3}\Sigma_{3 \times 3}V^T_{3\times n}$$
# <img src="1.jpeg" width="40%">
#
# ### 请你写一写用三个奇异值来近似原矩阵的代码
# （即计算$U_{m\times 3}\Sigma_{3 \times 3}V^T_{3\times n}$）

# %%
# 作业：添加你的代码

# %% [markdown]
# 可以看到，只用3个奇异值我们就很大程度上近似出了原矩阵，这也就是用SVD图片压缩的实现方法。
#
# 我们是如何知道仅需保留3个奇异值的呢？一种简单的方法是直接规定奇异值的数量，但是这样我们就没有把奇异值的分布情况考虑进去，有的图可能只有一个特别大的奇异值，有的图可能奇异值大小都比较平均。
#
# 确定要保留的奇异值的数目有很多启发式策略，其中一个典型的做法就是保留矩阵中90%的能量信息。
#
# 为了计算总能量信息，我们将所有的奇异值平方后求和。于是可以将奇异值的平方和从大到小累加到总值的90%为止。
#
# 接下来我们来看一个将SVD应用于图像压缩的例子。通过TKinter可视化的方式，我们将会很容易看到SVD对数据近似的效果。
#
# # 基于SVD的图像压缩 + Tkinter库可视化
#
# ### 目标：
# 1. 使用TKinter来可视化压缩后的图片。（框架已经写好）
# 2. 要求有一个输入框用来输入保留的奇异值个数，要求默认值是保留90%以上能量的最小奇异值个数。（输入框已经写好，默认值请你计算）
# 3. 点击“Display“按钮后，显示新的近似图像。（按钮和重构图像需要你来实现，分别参考tkinter的Button和之前讲的SVD）
# 4. 在近似图像的右边画一张图，表示【奇异值保留的能量百分比】与【奇异值个数】的关系。（需要你来实现，参考plt的使用方法）
# 5. 在显示近似图像的时候，显示保留的奇异值个数和奇异值保留的能量百分比。（需要你来实现，参考tkinter的Label）
# 6. （选做）增加一个输入框或者就在原输入框中输入[0.0, 1.0]的小数，显示保留这么多能量情况下的近似图片。
#
# 下图是一个可能的例子（不用做到完全一样），不过这里第2\5\6点还未实现。
#
# <img src="2.png" width="60%">
#
# ### 注意：
#
# - 图片是三通道的，转化为numpy array的时候可以看到形状是$height \times width \times 3$，对三个矩阵都做一次SVD即可。
# - 第2点中的最小奇异值个数用三个通道各自的最小值的最大值来表示。
# - 代码可以随意改，这里只是提供了一个可行的框架，实现功能即可。
#
# ### 检查要点：
# - 要有“Display“按钮，且点击之后图片会根据输入框里的值重新近似并显示。
# - 输入框默认值正确（只要不相差太多都算对）。
# - 保留能量百分比与奇异值个数的关系图画的趋势接近就算正确。
# - 在界面中可以看到当前的图片中保留了几个奇异值和保留的能量百分比。

# %%
import numpy as np
from PIL import Image

img = Image.open("example.jpeg")
arr = np.array(img)  # [height, width, channel(3)]

# %%
def compress(arr, numSV):
    '''
        对图片进行SVD分解，然后保留前numSV个奇异值，获得近似图片
    '''
    return arr

# %%
import matplotlib.pyplot as plt
from matplotlib.figure import Figure
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from tkinter import *
from PIL import Image

def display(numSV):
    display.f.clf()
    display.a = display.f.add_subplot(121)
    display.b = display.f.add_subplot(122)
    new_arr = compress(arr, numSV)
    img = Image.fromarray(new_arr)
    display.a.imshow(img)
    '''
        在display.b上画出保留能量百分比与奇异值个数的关系：
    '''
    display.canvas.draw() # 刷新画布


root = Tk()
root.title("基于SVD的图像压缩")
display.f = Figure(figsize=(6,3), dpi=120) # create canvas
display.canvas = FigureCanvasTkAgg(display.f, master=root)
display.canvas.draw()
display.canvas.get_tk_widget().grid(row=0, columnspan=3)

Label(root, text="奇异值个数").grid(row=1, column=0)
tolNentry = Entry(root)
tolNentry.grid(row=1, column=1)
tolNentry.insert(0, '10')

'''
    添加一个Button，使得点击时，根据输入的奇异值个数重新近似图片：
'''
display(10)

root.mainloop()
