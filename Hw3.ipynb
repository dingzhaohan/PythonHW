# %% [markdown]
# ### Python程序设计与数据挖掘导论
# ## 第三次作业
# 大家好，我是这次python课程作业！
# （注意看最后的提交方式）

# %% [markdown]
# #### Question 1：
# 给定n元1次方程组，通过**高斯消元法**和**矩阵乘法**两种方法求解方程。
#
# **输入**：该方程组的系数矩阵（包括各个方程的常数项，方程等号右边为0，shape=n x (n+1)）
#      例如：
#          $$
#             \begin{cases}
#                 x_1 + x_2 + 2 = 0\\
#                 x_1 + 2x_2 + 5 = 0
#             \end{cases}
#          $$
#         的输入为np.arrary([[1,1,2],[1,2,5]])。即：
#         $$
#             \begin{matrix} 1 & 1 & 2 \\ 1 & 2 & 5  \end{matrix}
#         $$
# **输出**：
#     解向量（n维numpy.array）
# 上述例子最后返回：np.array([1,-3])
# *提示：需要特判，若原方程组无解或无唯一解时，返回-1，判断方法不做限制*

# %%
import numpy as xxx # you can change this line, and import numpy as whatever you want. e.g. np, npy, nonpy...

# finish the function below
def SolveEquationSet_Gauss(matrix): # matrix is the Coefficient Matrix with Constant Term in numpy.array format.
    return None # the function should return the solution vector in numpy.array format. "None" is just a placeholder here.

def SolveEquationSet_MatMulti(matrix):
    return None # similar to the function before, but solve the equation set in another way.

# %% [markdown]
# #### Question 2: 斐波那契数列
# 斐波那契数列(前几项为：[0, 1, 1, ...])：
# 模仿课堂上求阶乘的方法，借助函数闭包，求斐波那契数列若干项（会输入一个列表），返回一个列表，需要通过闭包实现“记忆化搜索”，会按运行时间排名（不会影响成绩）。

# %%
# finish the function below
def solve(n): # this function return the n-th number of Fibonacci
    # ...
    return -1

def Fibonacci(query): # query is the list of number you should consider
    result = []
    for n in query:
        result.append(solve(n))
    return result

# %% [markdown]
# #### Question 3: 滑雪
# 周末，小费、小邓、小许、小王四个好朋友去滑雪，他们来到世界一流的未名滑雪场，他们从四个不同地方出发，根据物理规律，他们只能从高的点滑向前后左右相邻的低的点，请计算使得四人最大的总滑雪步数，若无法满足（如场地少于4个点），则返回-1。
# **输入：**
# 地图高度的列表（2维数组，numpy.array格式）
# **输出：**
# 四人最大总滑雪步数
#
# 例如：
# 输入:
# [[1,2,3],
#  [1,2,3],
#  [1,2,3]]
# 输出：
# 7

# %%
def skiing(matrix):
    return -1

# %% [markdown]
# #### Question 4: 投针实验
# 3月14日是喜闻乐见的国bai际se圆qing周ren率jie日，这一天小费十分激动，他想到了曾经学过的投针实验，于是他想写一个python程序来模拟实验，拟合圆周率，但是作为一个资深的C程序员，他对python有些陌生，请你帮助小费完成代码。
# *提示：借助numpy的random函数或者python自己的random函数生成“针”的位置和角度，再判断“针”十分与横线接触，最后统计频率*
# 最终得到频率，计算pi，利用plotting绘制随着抛的次数的增加，计算值趋向精确值的趋势。
# 数学知识：$ p=\frac{2 l}{\pi a}$，其中p为接触线的概率，l为针的长度($l\le a$)，a为横线间距。
#
# 抛针次数建议取为500000，请最终将plot生成的图片保存至本地，plot图上请标出自己的曲线和y=pi这条直线，图片标题和文件名为学号，格式为jpg（效果如下）。（pi的精度根据 import math math.pi 决定）

# %% [markdown]
# ![Hw3](./pi.jpg)

# %% [markdown]
# #### Question 5: 消息订阅模型-续
# 小王同学学习了计算机网络的课程，他联想到上次python作业，决定改进一下消息订阅模型。
# 基本要求与上次作业一致，即：
# **Publisher（发布者）**
#     - 保存订阅的读者
#     - 保存已发布的消息
#     - 发布新消息时，发布给所有已订阅的读者
#
#     共有三个发布者：PKU， THU， RUC
#
# **Reader（读者）**
#     - 订阅/取消订阅 发布者
#     - 保存发布者发来的消息
#
#     读者分为两种类型：
#         - Type1：不区分不同发布者的消息
#         - Type2：区分不同发布者的消息
#
#     共有三个读者：Alice，Bob，Carol  Alice和Bob为Type1， Carol为Type2
#
# **本次作业新的要求：**
# 1、发布者与读者之间的消息有3种类型：通知(0)、新闻(1)、学术(2)。每次发送消息模仿网络通信，有“header”和“body”两部分，header记录当前发送消息的类型和内容，即：
# 当发布者PKU发布“学术(2)”消息给接收方Alice时，消息内容为“python是世界上最好的语言”，则实际发送内容应该设定为"<2><python是世界上最好的语言>"
# 2、最终需要通过html网页的形式打印内容，请实现发布者、读者Type1、读者Type2不同的网页输出格式，内容格式通过css实现，网页内容需要包括：
#     - 当前用户类型：发布者、读者Type1、读者Type2
#     - 当前用户名（e.g. Alice, PKU, ...）
#     - 发布者需打印当前的订阅者，读者需打印当前订阅的发布者
#     - 当前发布/接收消息列表（不需打印确认消息，不同类型的消息以不同格式打印)
#     - “通知”要求使用红色字体，“新闻”要求使用蓝色字体，“学术”要求使用绿色字体，可以通过css增加更多特性，效果出色的有加分
#     - 得到的html文件分别命名为：学号-名称.html，如：1600012abc-Alice.html, 1600012abc-PKU.html...
#
# html参考网址：http://www.w3school.com.cn/html/index.asp
# css参考网址：http://www.w3school.com.cn/css/index.asp

# %%
# 发布者的基类
class BasePublisher(object):
    def __init__(self):
        # BasePublisher 的初始化方法
        # TODO

    def subscribeReader(self, reader):
        # Publisher 端的订阅函数
        # TODO

    def unsubscribeReader(self, reader):
        # Publisher 端的取消订阅函数
        # TODO

    def notifyReader(self, new):
        pass


# 北大
class PKUPublisher(BasePublisher):
    def __init__(self):
        # PKUPublisher 的初始化方法
        # TODO
        self.name = 'PKUPublisher'

    def notifyReader(self, new):
        # Publisher 向 Reader 发布消息
        # TODO

# 清华
class THUPublisher(BasePublisher):
    def __init__(self):
        # THUPublisher 的初始化方法
        # TODO
        self.name = 'THUPublisher'

    def notifyReader(self, new):
        # Publisher 向 Reader 发布消息
        # TODO


# 人大
class RUCPublisher(BasePublisher):
    def __init__(self):
        # RUCPublisher 的初始化方法
        # TODO
        self.name = 'RUCPublisher'

    def notifyReader(self, new):
        # Publisher 向 Reader 发布消息
        # TODO


# 读者基类
class BaseReader(object):
    def __init__(self):
        # BaseReader 的初始化方法
        # TODO

    def subscribeToPublisher(self, publisher):
        # Reader向Publisher订阅
        # TODO

    def unsubscribeToPublisher(self, publisher):
        # Reader向Publisher取消订阅
        # TODO

    def receiveNew(self, publisher, new):
        pass


# 第一种读者
class ReaderType1(BaseReader):
    def __init__(self, _name):
        # TODO

    def subscribeToPublisher(self, publisher):
        # Reader向Publisher订阅
        # TODO

    def receiveNew(self, publisher, new):
        # Reader 从 Publisher 接收消息
        # TODO


# 第二种读者
class ReaderType2(BaseReader):
    def __init__(self, _name):
        # TODO

    def subscribeToPublisher(self, publisher):
        # Reader向Publisher订阅
        # TODO

    def receiveNew(self, publisher, new):
        # TODO

# !!!! 新的部分
def wrapper(tp, msg):
    # TODO wrap the msg into <tp><msg>, please use string.format

def unwrapper(msg):
    # TODO: unwrap the msg and return the type and content. please use regex here


# 创建三个发布者对象
pkuPublisher = PKUPublisher()
thuPublisher = THUPublisher()
rucPublisher = RUCPublisher()

# 创建三位读者，alice 和 bob 为 第一类， tom 为 第二类
alice = ReaderType1('alice')
bob = ReaderType1('bob')
carol = ReaderType2('carol')

# alice 订阅了 pku， thu
alice.subscribeToPublisher(pkuPublisher)
alice.subscribeToPublisher(thuPublisher)

# bob 订阅了 thu， ruc
bob.subscribeToPublisher(thuPublisher)
bob.subscribeToPublisher(rucPublisher)

# tom 订阅了 pku， thu， ruc
carol.subscribeToPublisher(pkuPublisher)
carol.subscribeToPublisher(thuPublisher)
carol.subscribeToPublisher(rucPublisher)

# 发布者发布新消息 通知(00)、新闻(01)、学术(10)
pkuPublisher.notifyReader(wrapper(0, "PKU通知"))
pkuPublisher.notifyReader(wrapper(1, "PKU新闻"))
pkuPublisher.notifyReader(wrapper(2, "PKU学术"))

thuPublisher.notifyReader(wrapper(0, "THU通知"))
thuPublisher.notifyReader(wrapper(1, "THU新闻"))
thuPublisher.notifyReader(wrapper(2, "THU学术"))

rucPublisher.notifyReader(wrapper(0, "RUC通知"))
rucPublisher.notifyReader(wrapper(1, "RUC新闻"))
rucPublisher.notifyReader(wrapper(2, "RUC学术"))

pkuPublisher.get_html()
thuPublisher.get_html()
rucPublisher.get_html()

alice.get_html()
bob.get_html()
carol.get_html()

# %% [markdown]
# **提交方式：**请将本次作业中所有函数放入一个普通.py文件下上传，请不要修改函数名，文件名称为 学号.py。
# 例如：
# 文件名：1600012abc.py
# ```
# import numpy as np
# import matplotlib.pyplot as plt
#
# def SolveEquationSet_Gauss(matrix):
#     return None
#
# def SolveEquationSet_MatMulti(matrix):
#     return None
#
# def solve(n):
#     ...
# def Fibonacci(query):
#     ...
# def skiing(matrix):
#     ...
# ...(plot)
# ```
